# %%
import pandas as pd

# %%
quotes= pd.read_csv(r"C:\Users\Betul Kaya\Desktop\quotes.csv")
quotes
# Out:
#                                                     quote  \
# 0       I'm selfish, impatient and a little insecure. ...
# 1       You've gotta dance like there's nobody watchin...
# 2       You know you're in love when you can't fall as...
# 3       A friend is someone who knows all about you an...
# 4       Darkness cannot drive out darkness: only light...
# ...                                                   ...
# 499704  I do believe the most important thing I can do...
# 499705  I'd say I'm a bit antimadridista although I do...
# 499706                                 The future is now.
# 499707  In all my life and in the future, I will alway...
# 499708    The future is as bright as the promises of God.
#
#                                                    author  \
# 0                                          Marilyn Monroe
# 1                                       William W. Purkey
# 2                                               Dr. Seuss
# ...

# %%
quotes.head(10)
# Out:
#                                                quote  \
# 0  I'm selfish, impatient and a little insecure. ...
# 1  You've gotta dance like there's nobody watchin...
# 2  You know you're in love when you can't fall as...
# 3  A friend is someone who knows all about you an...
# 4  Darkness cannot drive out darkness: only light...
# 5            We accept the love we think we deserve.
# 6  Only once in your life, I truly believe, you f...
# 7  It is better to be hated for what you are than...
# 8  As he read, I fell in love the way you fall as...
# 9  The opposite of love is not hate, it's indiffe...
#
#                                               author  \
# 0                                     Marilyn Monroe
# 1                                  William W. Purkey
# 2                                          Dr. Seuss
# 3                                     Elbert Hubbard
# 4  Martin Luther King Jr., A Testament of Hope: T...
# 5   Stephen Chbosky, The Perks of Being a Wallflower
# ...

# %%
quotes[quotes["category"]=="love"]
# Out:
#                                                     quote  \
# 6       Only once in your life, I truly believe, you f...
# 8       As he read, I fell in love the way you fall as...
# 13      Have you ever been in love? Horrible isn't it?...
# 16      There is never a time or place for true love. ...
# 19      You may not be her first, her last, or her onl...
# ...                                                   ...
# 409852  Some pray to marry the man they love  My praye...
# 409853  'Tis better to have loved and lost  Than never...
# 409854  "I'm sorry that I spell'd the word  I hate to ...
# 409855  Werther had a love for Charlotte  Such as word...
# 409856             Love in its essence is spiritual fire.
#
#                                        author category
# 6                                  Bob Marley     love
# 8          John Green, The Fault in Our Stars     love
# 13               Neil Gaiman, The Kindly Ones     love
# ...

# %%
choice = input("Please enter what type of quotes you want.")
result=quotes[quotes["category"]==choice].sample()
result[["quote","author"]]
# Out:
# Please enter what type of quotes you want.love
#                                                  quote          author
# 368  I have feelings too. I am still human. All I w...  Marilyn Monroe
